# %%
import networkx as nx
import dhlab.graph_networkx_louvain as gnl

# %%
g = nx.read_gexf("bokstav-c+bigram.gexf")

# %%
g = nx.read_gexf("bokstav-c-bi.gexf")

# %%
g = nx.read_gexf("bokstav-c+bigram2.gexf")

# %%
g = nx.read_gexf("bokstaver-paradigme3.gexf")

# %%
g = nx.read_gexf("bokstaver-s2.gexf")

# %%
g = nx.read_gexf("bokstaver_paradigme2.gexf")

# %%
g = nx.read_gexf("bokstav-c-t-c.gexf")

# %%
gnl.show_graph(g, fontsize=20)

# %%
gnl.show_communities(g)
# Out:
# e-å :  e, å, i, a, u, o, y, ø, æ, é, ô, ü
#
# n-r :  n, r, v, d, s, t, g, k, m, p, b, l, h, j, c, w, z
#
# f-ä :  f, ä
#
# 8-0 :  8, 0, 5, 7, 1, 2, 3, 9, 4, 6
#
#  :
#
# q :  q
#
# § :  §
#
# ö :  ö
#
# x :  x
